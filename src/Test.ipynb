# %%
import tensorflow as tf
tf.compat.v1.disable_eager_execution()

# %%
from record import record
import time
filename = './log_folder/record.txt'
r = record(filename,time.time())
from mnistTestSuite_adv_test import mnist_lstm_adv_test
threshold_SC=0.6
threshold_BC=0.8
symbols_TC=3
seq=[4,24]
TestCaseNum=10000
Mutation='random'
CoverageStop=0.9

# %%
mnist_lstm_adv_test(r, threshold_SC, threshold_BC, symbols_TC, seq, TestCaseNum, Mutation, CoverageStop)
# Out:
# 2021-07-08 17:04:47.186680: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /Users/nhanitvn/Library/Caches/pypoetry/virtualenvs/aiquality-Jpiik8bc-py3.8/lib/python3.8/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 28, 128)           80384
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                4128
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 216,426
# Trainable params: 216,426
# Non-trainable params: 0
# _________________________________________________________________
# /Users/nhanitvn/Library/Caches/pypoetry/virtualenvs/aiquality-Jpiik8bc-py3.8/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:2426: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 128 features to be covered for NC
# 1280 features to be covered for KMNC
# 256 features to be covered for NBC
# 128 features to be covered for SANC
# 21 features to be covered for SC
# 21 features to be covered for BC
# 243 features to be covered for TC
#
# -----------------------------------------------------
# 1000 samples, within which there are 13 adversarial examples
# the rate of adversarial examples is 0.01
#
# neuron coverage up to now: 0.00
#
# KMNC up to now: 0.89
#
# NBC up to now: 0.77
#
# SANC up to now: 0.00
#
# Step-wise Coverage up to now: 0.33
#
# Boundary Coverage up to now: 0.19
#
# Temporal Coverage up to now: 0.46
#
# ------------------------------------------------------
# 2000 samples, within which there are 37 adversarial examples
# the rate of adversarial examples is 0.02
#
# neuron coverage up to now: 0.00
#
# KMNC up to now: 0.90
#
# NBC up to now: 0.79
#
# SANC up to now: 0.00
#
# Step-wise Coverage up to now: 0.33
#
# Boundary Coverage up to now: 0.24
#
# Temporal Coverage up to now: 0.55
#
# ------------------------------------------------------
# 3000 samples, within which there are 59 adversarial examples
# the rate of adversarial examples is 0.02
#
# neuron coverage up to now: 0.00
#
# KMNC up to now: 0.90
#
# NBC up to now: 0.79
#
# SANC up to now: 0.00
#
# Step-wise Coverage up to now: 0.38
#
# Boundary Coverage up to now: 0.24
#
# Temporal Coverage up to now: 0.56
#
# ------------------------------------------------------
# 4000 samples, within which there are 80 adversarial examples
# the rate of adversarial examples is 0.02
#
# neuron coverage up to now: 0.00
#
# KMNC up to now: 0.90
#
# NBC up to now: 0.79
#
# SANC up to now: 0.00
#
# Step-wise Coverage up to now: 0.38
#
# Boundary Coverage up to now: 0.29
#
# Temporal Coverage up to now: 0.58
#
# ------------------------------------------------------
# 5000 samples, within which there are 93 adversarial examples
# the rate of adversarial examples is 0.02
#
# neuron coverage up to now: 0.00
#
# KMNC up to now: 0.90
#
# NBC up to now: 0.79
#
# SANC up to now: 0.00
#
# Step-wise Coverage up to now: 0.38
#
# Boundary Coverage up to now: 0.29
#
# Temporal Coverage up to now: 0.60
#
# ------------------------------------------------------
# 6000 samples, within which there are 118 adversarial examples
# the rate of adversarial examples is 0.02
#
# neuron coverage up to now: 0.00
#
# KMNC up to now: 0.90
#
# NBC up to now: 0.79
#
# SANC up to now: 0.00
#
# Step-wise Coverage up to now: 0.43
#
# Boundary Coverage up to now: 0.29
#
# Temporal Coverage up to now: 0.62
#
# ------------------------------------------------------
# 7000 samples, within which there are 136 adversarial examples
# the rate of adversarial examples is 0.02
#
# neuron coverage up to now: 0.00
#
# KMNC up to now: 0.90
#
# NBC up to now: 0.79
#
# SANC up to now: 0.00
#
# Step-wise Coverage up to now: 0.43
#
# Boundary Coverage up to now: 0.29
#
# Temporal Coverage up to now: 0.63
#
# ------------------------------------------------------
# 8000 samples, within which there are 153 adversarial examples
# the rate of adversarial examples is 0.02
#
# neuron coverage up to now: 0.00
#
# KMNC up to now: 0.90
#
# NBC up to now: 0.79
#
# SANC up to now: 0.00
#
# Step-wise Coverage up to now: 0.43
#
# Boundary Coverage up to now: 0.29
#
# Temporal Coverage up to now: 0.63
#
# ------------------------------------------------------
# 9000 samples, within which there are 171 adversarial examples
# the rate of adversarial examples is 0.02
#
# neuron coverage up to now: 0.00
#
# KMNC up to now: 0.90
#
# NBC up to now: 0.79
#
# SANC up to now: 0.00
#
# Step-wise Coverage up to now: 0.43
#
# Boundary Coverage up to now: 0.29
#
# Temporal Coverage up to now: 0.64
#
# ------------------------------------------------------
# 10000 samples, within which there are 188 adversarial examples
# the rate of adversarial examples is 0.02
#
# neuron coverage up to now: 0.00
#
# KMNC up to now: 0.91
#
# NBC up to now: 0.79
#
# SANC up to now: 0.00
#
# Step-wise Coverage up to now: 0.43
#
# Boundary Coverage up to now: 0.29
#
# Temporal Coverage up to now: 0.64
#
# ------------------------------------------------------
# statistics:
#
# neuron coverage up to now: 0.00
#
# KMNC up to now: 0.91
#
# NBC up to now: 0.79
#
# SANC up to now: 0.00
#
# Step-wise Coverage up to now: 0.43
#
# Boundary Coverage up to now: 0.29
#
# Temporal Coverage up to now: 0.64
#
# ------------------------------------------------------
# unique adv. 9
# 10000 samples, within which there are 188 adversarial examples
# the rate of adversarial examples is 0.02
